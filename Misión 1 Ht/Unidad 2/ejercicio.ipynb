# %% [markdown]
# <a href="https://colab.research.google.com/github/diegofescg/TalentoTech/blob/main/ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# create a dataset

value_p_list = ['Morrales','Correas','Billeteras', 'Bolsos','Zapatos','Chaquetas','Jeans','Camisas','Buzos','Camisetas'] #Productos
value_uv_list = [32, 40, 55, 39, 23, 22, 23, 37, 39, 50] #Unidades vendidas
value_in_list = [2700000, 2000000, 1500000, 1800000, 3450000, 1540000, 1610000, 1665000, 3120000, 2400000] #Ingresos

#Let's use a dcitionary
#with the format
data_dict = {"Producto":value_p_list,
             "Unidades vendidas":value_uv_list,
             "Ingresos":value_in_list}


df = pd.DataFrame(data_dict)

df
# Out:
#      Producto  Unidades vendidas  Ingresos
# 0    Morrales                 32   2700000
# 1     Correas                 40   2000000
# 2  Billeteras                 55   1500000
# 3      Bolsos                 39   1800000
# 4     Zapatos                 23   3450000
# 5   Chaquetas                 22   1540000
# 6       Jeans                 23   1610000
# 7     Camisas                 37   1665000
# 8       Buzos                 39   3120000
# 9   Camisetas                 50   2400000

# %%
df.stats = df.describe()

df.stats
# Out:
# <ipython-input-11-dd9a512c8e4b>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.stats = df.describe()
#        Unidades vendidas      Ingresos
# count          10.000000  1.000000e+01
# mean           36.000000  2.178500e+06
# std            11.264497  7.034994e+05
# min            22.000000  1.500000e+06
# 25%            25.250000  1.623750e+06
# 50%            38.000000  1.900000e+06
# 75%            39.750000  2.625000e+06
# max            55.000000  3.450000e+06
